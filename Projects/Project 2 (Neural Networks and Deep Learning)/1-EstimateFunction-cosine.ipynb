# %%
# !pip install torchviz

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchviz) (1.10.0+cu111)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchviz) (3.10.0.2)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4150 sha256=2e4c3832c9565f350e9cf1f64e4882cc16e59f07e7550d0de609ddceaf780b21
#   Stored in directory: /root/.cache/pip/wheels/04/38/f5/dc4f85c3909051823df49901e72015d2d750bd26b086480ec2
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2

# %%
x = np.linspace(-5, 5, 1000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

model = nn.Sequential(nn.Linear(1, 100), nn.ReLU(), nn.Linear(100, 1))
optimizer = optim.Adam(model.parameters(), lr = 0.005)
loss_func = nn.MSELoss()

losses = []
for i in range(0, 10):
  optimizer.zero_grad()
  loss = loss_func(model(x_torch), y_torch)
  loss.backward()
  optimizer.step()
  losses.append(loss.item())
print(losses)
# Out:
# [0.87806236743927, 0.4524588882923126, 0.3392913341522217, 0.4117928147315979, 0.4824984073638916, 0.4764344096183777, 0.4190802276134491, 0.35720986127853394, 0.3208370506763458, 0.31376662850379944]

# %%
x = np.linspace(-5, 5, 10000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

plt.plot(x, y, 'g', label = 'Original Function')
plt.plot(x_torch.detach().numpy().flatten(), model(x_torch).detach().numpy().flatten(), 'r', label = 'Predicted Function')
plt.show()

# %%
x = np.linspace(-5, 5, 20)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

model = nn.Sequential(nn.Linear(1, 100), nn.ReLU(), nn.Linear(100, 1))
optimizer = optim.Adam(model.parameters(), lr = 0.005)
loss_func = nn.MSELoss()

losses = []
for i in range(0, 1000):
  optimizer.zero_grad()
  loss = loss_func(model(x_torch), y_torch)
  loss.backward()
  optimizer.step()
  losses.append(loss.item())
print(losses)
# Out:
# [1.4233875274658203, 0.918655276298523, 0.6026647686958313, 0.4525907635688782, 0.44135451316833496, 0.5015446543693542, 0.5695874691009521, 0.5960855484008789, 0.5775686502456665, 0.5246869325637817, 0.4569443166255951, 0.39561837911605835, 0.3507137894630432, 0.32870087027549744, 0.32824331521987915, 0.33967339992523193, 0.35460370779037476, 0.3637346625328064, 0.3614136278629303, 0.34862980246543884, 0.32771986722946167, 0.30415409803390503, 0.2835564613342285, 0.2686062455177307, 0.26126450300216675, 0.26002296805381775, 0.26172199845314026, 0.2634832561016083, 0.2620030343532562, 0.2565303146839142, 0.24751286208629608, 0.23644497990608215, 0.22592361271381378, 0.21725896000862122, 0.2116270363330841, 0.2085665911436081, 0.2071916162967682, 0.20596635341644287, 0.20366528630256653, 0.1998961865901947, 0.19457677006721497, 0.18868806958198547, 0.182946115732193, 0.17825737595558167, 0.17474298179149628, 0.17228803038597107, 0.17028109729290009, 0.1681986153125763, 0.16551242768764496, 0.1621568500995636, 0.15841610729694366, 0.15466968715190887, 0.15125766396522522, 0.14840981364250183, 0.14604800939559937
293847561, 0.019739780575037003, 0.019221438094973564, 0.01871909573674202, 0.018231894820928574, 0.017759554088115692, 0.017301730811595917, 0.01685767062008381, 0.01642666757106781, 0.01600867696106434, 0.015603102743625641, 0.015209372155368328, 0.014827138744294643, 0.014456157572567463, 0.014095854945480824, 0.01374591700732708, 0.013406038284301758, 0.01307594683021307, 0.01275536697357893, 0.012443977408111095, 0.012141657993197441, 0.011848103255033493, 0.011563137173652649, 0.011286495253443718, 0.011018066667020321, 0.010757599025964737, 0.010504805482923985, 0.010259563103318214, 0.010021544061601162, 0.009790572337806225, 0.009566409513354301, 0.009348801337182522, 0.009137578308582306, 0.00893250573426485, 0.008733352646231651, 0.008540055714547634, 0.00835234671831131, 0.008170164190232754, 0.007993335835635662, 0.007821683771908283, 0.007655016612261534, 0.0074932328425347805, 0.00733622582629323, 0.007183776702731848, 0.00703571317717433, 0.006891949567943811, 0.006752300076186657, 0.006616632919758558, 0.006484802346676588, 0.006356646306812763, 0.006232049781829119, 0.006110875867 ...

# %%
x = np.linspace(-5, 5, 10000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

plt.plot(x, y, 'g', label = 'Original Function')
plt.plot(x_torch.detach().numpy().flatten(), model(x_torch).detach().numpy().flatten(), 'r', label = 'Predicted Function')
plt.show()

# %%
x = np.linspace(-10, 10, 20000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

plt.plot(x, y, 'g', label = 'Original Function')
plt.plot(x_torch.detach().numpy().flatten(), model(x_torch).detach().numpy().flatten(), 'r', label = 'Predicted Function')
plt.show()

# %%
x = np.linspace(-5, 5, 1000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

model = nn.Sequential(nn.Linear(1, 100), nn.ReLU(), nn.Linear(100, 1))
optimizer = optim.Adam(model.parameters(), lr = 0.5)
loss_func = nn.MSELoss()

losses = []
for i in range(0, 1000):
  optimizer.zero_grad()
  loss = loss_func(model(x_torch), y_torch)
  loss.backward()
  optimizer.step()
  losses.append(loss.item())
print(losses)
# Out:
# [0.518679678440094, 2634.68603515625, 90.40362548828125, 33.89274978637695, 63.68278121948242, 21.609580993652344, 12.346320152282715, 42.34901809692383, 83.45030212402344, 88.51873779296875, 119.31023406982422, 85.24227142333984, 73.88673400878906, 57.185546875, 9.687291145324707, 28.88156509399414, 30.057266235351562, 24.628507614135742, 27.247303009033203, 14.516444206237793, 30.04743194580078, 30.600866317749023, 6.533989906311035, 17.50962257385254, 25.925701141357422, 6.5833024978637695, 8.935652732849121, 19.184350967407227, 9.204215049743652, 6.3228607177734375, 12.697993278503418, 9.367910385131836, 6.294037818908691, 8.69052505493164, 7.971668243408203, 6.107607841491699, 6.325261116027832, 5.759116172790527, 4.238763332366943, 3.935250997543335, 4.2679572105407715, 3.9443910121917725, 3.314932346343994, 3.336789846420288, 3.8511202335357666, 3.7960729598999023, 2.7777204513549805, 1.8409591913223267, 2.046377420425415, 2
plt.plot(x_torch.detach().numpy().flatten(), model(x_torch).detach().numpy().flatten(), 'r', label = 'Predicted Function')
plt.show()

# %%
x = np.linspace(-5, 5, 1000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

model = nn.Sequential(nn.Linear(1, 10), nn.ReLU(), nn.Linear(10, 1))
optimizer = optim.Adam(model.parameters(), lr = 0.005)
loss_func = nn.MSELoss()

losses = []
for i in range(0, 1000):
  optimizer.zero_grad()
  loss = loss_func(model(x_torch), y_torch)
  loss.backward()
  optimizer.step()
  losses.append(loss.item())
print(losses)
# Out:
# [0.4729153513908386, 0.45274123549461365, 0.4352649748325348, 0.4205915629863739, 0.4085698127746582, 0.3990480303764343, 0.39166930317878723, 0.3858668804168701, 0.38104763627052307, 0.37662261724472046, 0.37213727831840515, 0.3673069477081299, 0.36204051971435547, 0.35640111565589905, 0.350542277097702, 0.3446425497531891, 0.33887138962745667, 0.33337149024009705, 0.3282332718372345, 0.3234790861606598, 0.3190726935863495, 0.3149423599243164, 0.311000794172287, 0.30716219544410706, 0.30335694551467896, 0.29954320192337036, 0.29571229219436646, 0.2918846309185028, 0.2880996763706207, 0.2844037115573883, 0.28084275126457214, 0.27745240926742554, 0.2742527425289154, 0.2712422013282776, 0.2684004604816437, 0.265693336725235, 0.26308053731918335, 0.26052504777908325, 0.257999986410141, 0.25549307465553284, 0.25300508737564087, 0.2505488693714142, 0.24813959002494812, 0.245791956782341, 0.24351593852043152, 0.2413128763437271, 0.23917637765407562, 0.23709630966186523, 0.23506078124046326, 0.23305870592594147, 0.23108568787574768, 0.2291407585144043, 0.22722749412059784, 0.22535333037376404, 0.22352281212806702, 0.2217390388250351, 0.22000302374362946, 0.2183087170124054, 0.21665039658546448, 0.21502022445201874, 0.21341048181056976, 0.21181724965572357, 0.21023869514465332, 0.20867550373077393, 0.20712973177433014, 0.20560222864151, 0.20409299433231354, 0.2026011198759079, 0.2011226862668991, 0.1996556967496872, 0.19819629192352295, 0.19674529135227203, 0.19530253112316132, 0.19386933743953705, 0.19244827330112457, 0.19103974103927612, 0.18964488804340363, 0.18826167285442352, 0.18689003586769104, 0.18552634119987488, 0.18417111039161682, 0.1828223317861557, 0.18148143589496613, 0.18014711141586304, 0.17882007360458374, 0.1774984896183014, 0.17618276178836823, 0.17487019300460815, 0.17356045544147491, 0.17225241661071777, 0.17094649374485016, 0.16964200139045715, 0.1683391034603119, 0.16703754663467407, 0.16573655605316162, 0.16443604230880737, 0.1631343513727188, 0.16183239221572876, 0.16052965819835663, 0.15922564268112183, 0.1579209864139557, 0.156615749001503, 0.15530870854854584, 0.15400007367134094, 0.1526906043291092, 0.15137863159179688, 0.15006472170352936, 0.1487497240304947, 0.1474328637123108, 0.14611420035362244, 0.1447940617799759, 0.14347265660762787, 0.14214923977851868, 0.1408240646123886, 0.13949766755104065, 0.1381703019142151, 0.13684134185314178, 0.13551147282123566, 0.13418129086494446, 0.13285064697265625, 0.13151882588863373, 0.13018682599067688, 0.12885470688343048, 0.12752264738082886, 0.12619145214557648, 0.12486052513122559, 0.12352973967790604, 0.1222006157040596, 0.12087226659059525, 0.11954619735479355, 0.11822199821472168, 0.11689898371696472, 0.11557883769273758, 0.11426084488630295, 0.11294601112604141, 0.11163506656885147, 0.11032666265964508, 0.1090228408575058, 0.10772236436605453, 0.10642644762992859, 0.10513526946306229, 0.10384826362133026, 0.10256805270910263, 0.10129197686910629, 0.10002239793539047, 0.09875819087028503, 0.0975005254149437, 0.09624961763620377, 0.09500517696142197, 0.09376831352710724, 0.09253819286823273, 0.0913161188364029, 0.09010123461484909, 0.08889444917440414, 0.08769594877958298, 0.0865061804652214, 0.08532467484474182, 0.0841517373919487, 0.08298778533935547, 0.08183319121599197, 0.08068773150444031, 0.07955136150121689, 0.07842478156089783, 0.07730789482593536, 0.076200932264328, 0.07510342448949814, 0.0740165039896965, 0.0729391798377037, 0.07187246531248093, 0.07081566005945206, 0.0697697326540947, 0.06873409450054169, 0.0677090436220169, 0.06669459491968155, 0.06569086015224457, 0.06469790637493134, 0.06371556967496872, 0.06274452805519104, 0.06178401783108711, 0.060834601521492004, 0.05989600345492363, 0.05896889418363571, 0.05805232748389244, 0.05714699998497963, 0.056252770125865936, 0.055369362235069275, 0.05449749901890755, 0.053636133670806885, 0.0527864545583725, 0.05194732919335365, 0.051119640469551086, 0.050302665680646896, 0.04949664697051048, 0.048 ...

# %%
x = np.linspace(-5, 5, 10000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

plt.plot(x, y, 'g', label = 'Original Function')
plt.plot(x_torch.detach().numpy().flatten(), model(x_torch).detach().numpy().flatten(), 'r', label = 'Predicted Function')
plt.show()

# %%
x = np.linspace(-5, 5, 1000)
x_torch = torch.unsqueeze(torch.from_numpy(x.astype(np.float32)), dim = 1)
y = np.cos(x)
y_torch = torch.cos(x_torch)

model = nn.Sequential(nn.Linear(1, 10), nn.ReLU(), nn.Linear(10, 100), nn.ReLU(), nn.Linear(100, 1))
optimizer = optim.Adam(model.parameters(), lr = 0.005)
loss_func = nn.MSELoss()

losses = []
for i in range(0, 1000):
  optimizer.zero_grad()
  loss = loss_func(model(x_torch), y_torch)
  loss.backward()
  optimizer.step()
  losses.append(loss.item())
print(losses)
# Out:
# [0.42812326550483704, 0.36158254742622375, 0.3375702500343323, 0.33186909556388855, 0.3199376165866852, 0.2969377934932709, 0.27333441376686096, 0.2569199204444885, 0.24867194890975952, 0.2436913102865219, 0.23611584305763245, 0.22399099171161652, 0.21074919402599335, 0.20157809555530548, 0.19787119328975677, 0.19609887897968292, 0.19187936186790466, 0.18404890596866608, 0.17558515071868896, 0.1695306897163391, 0.16598094999790192, 0.1623220592737198, 0.15683487057685852, 0.15040099620819092, 0.14481717348098755, 0.14062801003456116, 0.13703052699565887, 0.13300195336341858, 0.12820792198181152, 0.12314297258853912, 0.11865454167127609, 0.11482985317707062, 0.11016464233398438, 0.10466664284467697, 0.09949193149805069, 0.09546453505754471, 0.09204264730215073, 0.08823182433843613, 0.08414853364229202, 0.08029244840145111, 0.07681944966316223, 0.073393814265728, 0.06960044056177139, 0.06594878435134888, 0.06288883090019226, 0.05973824858665466, 0.05639176815748215, 0.0533374585211277, 